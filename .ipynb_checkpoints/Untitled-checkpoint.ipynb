# %%
import sys
from openpyxl import Workbook, load_workbook
import pyodbc
import datetime
import os

# %%
main_path = os.getcwd()
main_path
# Out:
# 'C:\\Users\\lucas\\VSCodeProjects\\TCC_Estácio_git'

# %%
file_path = os.path.join(main_path, 'modules\\sql')
file_path
# Out:
# 'C:\\Users\\lucas\\VSCodeProjects\\TCC_Estácio_git\\modules\\sql'

# %%
sys.path.append(file_path)

# %%
import sql_manipulation as mnp

# %%
BNCC = mnp.Table('BNCC')

# %%
BNCC.columns
# Out:
# ['id_competence',
#  'school_year',
#  'theme',
#  'competence_description',
#  'register_date',
#  'register_user']

# %%
        max_iter = len(BNCC.columns) - 1

        for c in range(0, max_iter):

            if c != max_iter:

                print(BNCC.columns[c], end="\t")

                next


            else:

                print(BNCC.columns[c])

        rows = BNCC.table_data

        for row in rows:

            for c in range(0, max_iter):

                if c != max_iter:

                    print(row[c], end="\t")

                    next


                else:

                    print(row[c])
# Out:
# id_competence	school_year	theme	competence_description	register_date	register_user	EF01MA01	EF01	Números	Utilizar números naturais como indicador de quantidade ou de ordem em diferentes situações cotidianas e reconhecer situações em que os números não indicam contagem nem ordem, mas sim código de identificação.	2023-06-02 10:48:21	lucas	EF01MA02	EF01	Números	Contar de maneira exata ou aproximada, utilizando diferentes estratégias como o pareamento e outros agrupamentos.	2023-06-02 10:48:21	lucas	EF01MA03	EF01	Números	Estimar e comparar quantidades de objetos de dois conjuntos (em torno de 20 elementos), por estimativa e/ou por correspondência (um a um, dois a dois) para indicar $tem mais”, $tem menos” ou $tem a mesma quantidade”.	2023-06-02 10:48:21	lucas	EF01MA04	EF01	Números	Contar a quantidade de objetos de coleções até 100 unidades e apresentar o resultado por registros verbais e simbólicos, em situações de seu interesse, como jogos, brincadeiras, materiais da sala de aula, entre
# ...

# %%
len(BNCC.columns)
# Out:
# 6
